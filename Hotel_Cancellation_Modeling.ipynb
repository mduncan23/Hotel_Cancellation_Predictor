# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Preperation" data-toc-modified-id="Data-Preperation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preperation</a></span><ul class="toc-item"><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Checking-Date-Range---Adding-Date-Column" data-toc-modified-id="Checking-Date-Range---Adding-Date-Column-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Checking Date Range - Adding Date Column</a></span></li><li><span><a href="#Adding-new-feature-total_stay" data-toc-modified-id="Adding-new-feature-total_stay-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Adding new feature <code>total_stay</code></a></span></li><li><span><a href="#Adding-New-Feature-total_stay_price" data-toc-modified-id="Adding-New-Feature-total_stay_price-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Adding New Feature <code>total_stay_price</code></a></span></li></ul></li><li><span><a href="#Changing-dtype-for-use-later-on-with-scaling." data-toc-modified-id="Changing-dtype-for-use-later-on-with-scaling.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Changing dtype for use later on with scaling.</a></span></li><li><span><a href="#Cleaning-up-the-Target-Variable" data-toc-modified-id="Cleaning-up-the-Target-Variable-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Cleaning up the Target Variable</a></span></li><li><span><a href="#Setting-up-a-pipeline" data-toc-modified-id="Setting-up-a-pipeline-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Setting up a pipeline</a></span></li><li><span><a href="#Setting-up-Train/Test-Split" data-toc-modified-id="Setting-up-Train/Test-Split-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Setting up Train/Test Split</a></span><ul class="toc-item"><li><span><a href="#Creating-Score-Cards-to-Keep-Track-of-Results" data-toc-modified-id="Creating-Score-Cards-to-Keep-Track-of-Results-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Creating Score Cards to Keep Track of Results</a></span></li></ul></li></ul></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Dummy-Model" data-toc-modified-id="Dummy-Model-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Dummy Model</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#Base-Model" data-toc-modified-id="Base-Model-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Base Model</a></span></li><li><span><a href="#Logistic-Regression-GridSearch-1" data-toc-modified-id="Logistic-Regression-GridSearch-1-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Logistic Regression GridSearch 1</a></span></li><li><span><a href="#Logistic-Regression-GridSearch-2" data-toc-modified-id="Logistic-Regression-GridSearch-2-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Logistic Regression GridSearch 2</a></span></li><li><span><a href="#Updating-Score-Card" data-toc-modified-id="Updating-Score-Card-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Updating Score Card</a></span></li></ul></li><li><span><a href="#SVC" data-toc-modified-id="SVC-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>SVC</a></span><ul class="toc-item"><li><span><a href="#Base-Model" data-toc-modified-id="Base-Model-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Base Model</a></span></li><li><span><a href="#SVC-Gridsearch-1" data-toc-modified-id="SVC-Gridsearch-1-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>SVC Gridsearch 1</a></span></li><li><span><a href="#SVC-GridSearch-2" data-toc-modified-id="SVC-GridSearch-2-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>SVC GridSearch 2</a></span></li><li><span><a href="#Updating-Score-Card" data-toc-modified-id="Updating-Score-Card-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Updating Score Card</a></span></li></ul></li><li><span><a href="#NuSVC" data-toc-modified-id="NuSVC-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>NuSVC</a></span><ul class="toc-item"><li><span><a href="#Base-Model" data-toc-modified-id="Base-Model-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Base Model</a></span></li><li><span><a href="#NuSVC-GridSearch-1" data-toc-modified-id="NuSVC-GridSearch-1-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>NuSVC GridSearch 1</a></span></li><li><span><a href="#NuSVC-GridSearch-2" data-toc-modified-id="NuSVC-GridSearch-2-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>NuSVC GridSearch 2</a></span></li><li><span><a href="#Updating-Score-Card" data-toc-modified-id="Updating-Score-Card-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Updating Score Card</a></span></li></ul></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Decision Tree</a></span><ul class="toc-item"><li><span><a href="#Base-Model" data-toc-modified-id="Base-Model-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Base Model</a></span></li><li><span><a href="#Reducing-Overfitting" data-toc-modified-id="Reducing-Overfitting-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Reducing Overfitting</a></span></li><li><span><a href="#Decision-Tree-GridSearch-1" data-toc-modified-id="Decision-Tree-GridSearch-1-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Decision Tree GridSearch 1</a></span></li><li><span><a href="#Decision-Tree-GridSearch-2" data-toc-modified-id="Decision-Tree-GridSearch-2-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Decision Tree GridSearch 2</a></span></li><li><span><a href="#Updating-Score-Card" data-toc-modified-id="Updating-Score-Card-2.5.5"><span class="toc-item-num">2.5.5&nbsp;&nbsp;</span>Updating Score Card</a></span></li></ul></li><li><span><a href="#Random-Forest-Model" data-toc-modified-id="Random-Forest-Model-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Random Forest Model</a></span><ul class="toc-item"><li><span><a href="#Reducing-Overfitting" data-toc-modified-id="Reducing-Overfitting-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Reducing Overfitting</a></span></li><li><span><a href="#Random-Forest-GridSearch-1" data-toc-modified-id="Random-Forest-GridSearch-1-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>Random Forest GridSearch 1</a></span></li><li><span><a href="#Random-Forest-GridSearch-2" data-toc-modified-id="Random-Forest-GridSearch-2-2.6.3"><span class="toc-item-num">2.6.3&nbsp;&nbsp;</span>Random Forest GridSearch 2</a></span></li><li><span><a href="#Updating-Score-Card" data-toc-modified-id="Updating-Score-Card-2.6.4"><span class="toc-item-num">2.6.4&nbsp;&nbsp;</span>Updating Score Card</a></span></li><li><span><a href="#Determining-Feature-Importance" data-toc-modified-id="Determining-Feature-Importance-2.6.5"><span class="toc-item-num">2.6.5&nbsp;&nbsp;</span>Determining Feature Importance</a></span></li></ul></li><li><span><a href="#K-Nearest-Neighbors" data-toc-modified-id="K-Nearest-Neighbors-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>K-Nearest Neighbors</a></span><ul class="toc-item"><li><span><a href="#Reduce-Overfitting" data-toc-modified-id="Reduce-Overfitting-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Reduce Overfitting</a></span></li><li><span><a href="#KNN-Gridsearch-1" data-toc-modified-id="KNN-Gridsearch-1-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>KNN Gridsearch 1</a></span></li><li><span><a href="#KNN-Gridsearch-2" data-toc-modified-id="KNN-Gridsearch-2-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>KNN Gridsearch 2</a></span></li><li><span><a href="#Updating-Scorecard" data-toc-modified-id="Updating-Scorecard-2.7.4"><span class="toc-item-num">2.7.4&nbsp;&nbsp;</span>Updating Scorecard</a></span></li></ul></li><li><span><a href="#Naive-Bayes---Bernoulli" data-toc-modified-id="Naive-Bayes---Bernoulli-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Naive Bayes - Bernoulli</a></span><ul class="toc-item"><li><span><a href="#Bernoulli-Gridsearch-1" data-toc-modified-id="Bernoulli-Gridsearch-1-2.8.1"><span class="toc-item-num">2.8.1&nbsp;&nbsp;</span>Bernoulli Gridsearch 1</a></span></li><li><span><a href="#Updating-Scorecard" data-toc-modified-id="Updating-Scorecard-2.8.2"><span class="toc-item-num">2.8.2&nbsp;&nbsp;</span>Updating Scorecard</a></span></li></ul></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>XGBoost</a></span><ul class="toc-item"><li><span><a href="#Reducing-Overfitting" data-toc-modified-id="Reducing-Overfitting-2.9.1"><span class="toc-item-num">2.9.1&nbsp;&nbsp;</span>Reducing Overfitting</a></span></li><li><span><a href="#XGBoost-Gridsearch-1" data-toc-modified-id="XGBoost-Gridsearch-1-2.9.2"><span class="toc-item-num">2.9.2&nbsp;&nbsp;</span>XGBoost Gridsearch 1</a></span></li><li><span><a href="#XGBoost-Gridsearch-2" data-toc-modified-id="XGBoost-Gridsearch-2-2.9.3"><span class="toc-item-num">2.9.3&nbsp;&nbsp;</span>XGBoost Gridsearch 2</a></span></li><li><span><a href="#Updating-Scorecard" data-toc-modified-id="Updating-Scorecard-2.9.4"><span class="toc-item-num">2.9.4&nbsp;&nbsp;</span>Updating Scorecard</a></span></li></ul></li><li><span><a href="#XGB-Random-Forest" data-toc-modified-id="XGB-Random-Forest-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>XGB Random Forest</a></span><ul class="toc-item"><li><span><a href="#XGB-Random-Forest-Gridsearch-1" data-toc-modified-id="XGB-Random-Forest-Gridsearch-1-2.10.1"><span class="toc-item-num">2.10.1&nbsp;&nbsp;</span>XGB Random Forest Gridsearch 1</a></span></li><li><span><a href="#XGB-Random-Forest-Gridsearch-2" data-toc-modified-id="XGB-Random-Forest-Gridsearch-2-2.10.2"><span class="toc-item-num">2.10.2&nbsp;&nbsp;</span>XGB Random Forest Gridsearch 2</a></span></li><li><span><a href="#Updating-Scorecard" data-toc-modified-id="Updating-Scorecard-2.10.3"><span class="toc-item-num">2.10.3&nbsp;&nbsp;</span>Updating Scorecard</a></span></li></ul></li><li><span><a href="#Stacking-Classifier" data-toc-modified-id="Stacking-Classifier-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Stacking Classifier</a></span><ul class="toc-item"><li><span><a href="#Stacking-1" data-toc-modified-id="Stacking-1-2.11.1"><span class="toc-item-num">2.11.1&nbsp;&nbsp;</span>Stacking 1</a></span></li><li><span><a href="#Stacking-2" data-toc-modified-id="Stacking-2-2.11.2"><span class="toc-item-num">2.11.2&nbsp;&nbsp;</span>Stacking 2</a></span></li><li><span><a href="#Stacking-3" data-toc-modified-id="Stacking-3-2.11.3"><span class="toc-item-num">2.11.3&nbsp;&nbsp;</span>Stacking 3</a></span></li><li><span><a href="#Stacking-4" data-toc-modified-id="Stacking-4-2.11.4"><span class="toc-item-num">2.11.4&nbsp;&nbsp;</span>Stacking 4</a></span></li><li><span><a href="#Stacking-5" data-toc-modified-id="Stacking-5-2.11.5"><span class="toc-item-num">2.11.5&nbsp;&nbsp;</span>Stacking 5</a></span></li><li><span><a href="#Stacking-6" data-toc-modified-id="Stacking-6-2.11.6"><span class="toc-item-num">2.11.6&nbsp;&nbsp;</span>Stacking 6</a></span></li><li><span><a href="#Stacking-Final" data-toc-modified-id="Stacking-Final-2.11.7"><span class="toc-item-num">2.11.7&nbsp;&nbsp;</span>Stacking Final</a></span></li></ul></li><li><span><a href="#Checking-Against-Validation-Data" data-toc-modified-id="Checking-Against-Validation-Data-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Checking Against Validation Data</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Results</a></span></li></ul></li><li><span><a href="#Conclusion-and-Recommendations" data-toc-modified-id="Conclusion-and-Recommendations-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Conclusion and Recommendations</a></span><ul class="toc-item"><li><span><a href="#Recap-of-Initial-Results" data-toc-modified-id="Recap-of-Initial-Results-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Recap of Initial Results</a></span></li><li><span><a href="#Modeling-Results" data-toc-modified-id="Modeling-Results-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Modeling Results</a></span></li></ul></li></ul></div>

# %%
# Basic imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Metrics and Modeling set-up imports
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer,  make_column_selector as selector
from sklearn.model_selection import train_test_split, cross_validate, learning_curve
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, \
                            accuracy_score, roc_auc_score, precision_score, \
                            recall_score, f1_score

# models
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, NuSVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.naive_bayes import BernoulliNB

from xgboost import XGBClassifier, XGBRFClassifier

# import custom scoring function
from functions import score_model, cv_score


# block warnings for better viewing
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data Source: https://www.kaggle.com/datasets/ahsan81/hotel-reservations-classification-dataset?resource=download

# %% [markdown]
# ![hotel_intro](./Images/Hotel_intro.jpg)

# %% [markdown]
# # Data Preperation

# %%
# pulling in data
df = pd.read_csv('./Data/Hotel Reservations.csv')

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Checking Date Range - Adding Date Column

# %% [markdown]
# Checking the date range for the data. There is data for February 29th for a year that does not have a leap year. To account for this, I have adjusted the date to be February 28th for any days that were incorrectly labeled.

# %%
# checking for any leap years
df['arrival_year'].min(), df['arrival_year'].max()
# Out:
# (2017, 2018)

# %%
# checking for any incorrect dates in February (no leap years in dataset)
df[df['arrival_month'] == 2].arrival_date.max()
# Out:
# 29

# %%
# replacing incorrectly labeled 2/29 with 2/28
df.loc[df['arrival_month'] == 2, 'arrival_date'] = df['arrival_date'].replace(29, 28)

# %%
# adding a combined date column
df['date'] = pd.to_datetime(df[['arrival_year', 'arrival_month', 'arrival_date']].
                            rename(columns={'arrival_year': 'year',
                                            'arrival_month': 'month', 
                                            'arrival_date': 'day'}))

# %%
# checking date range
df.date.min(), df.date.max()
# Out:
# (Timestamp('2017-07-01 00:00:00'), Timestamp('2018-12-31 00:00:00'))

# %% [markdown]
# ### Adding new feature `total_stay`

# %% [markdown]
# Adding feature `total_stay` to account for all weekday and week end stays together.

# %%
df['total_stay'] = df['no_of_week_nights'] + df['no_of_weekend_nights']

# %%
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  ...  arrival_date  \
# 0        Room_Type 1        224          2017  ...             2
# ...

# %% [markdown]
# ### Adding New Feature `total_stay_price`

# %% [markdown]
# Adding feature `total_stay_price` to account for the total price for all days stayed.

# %%
df['total_stay_price'] = df['total_stay'] * df['avg_price_per_room']

# %%
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  ...  market_segment_type  \
# 0        Room_Type 1        224          2017  ...              Offline
# ...

# %% [markdown]
# ## Changing dtype for use later on with scaling.

# %% [markdown]
# I only want to scale continuous features and will convert them to float type to select just those features later on.

# %%
# cols to convert to float type
cols_to_float = ['no_of_weekend_nights', 'no_of_week_nights', 'lead_time', 
                 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
                 'avg_price_per_room', 'no_of_special_requests', 'total_stay',
                 'total_stay_price']

# %%
# converting cols to float type
for col in cols_to_float:
    df[col] = df[col].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  float64
#  4   no_of_week_nights                     36275 non-null  float64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  float64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %% [markdown]
# ## Cleaning up the Target Variable

# %%
df['booking_status'].value_counts()
# Out:
# Not_Canceled    24390
# Canceled        11885
# Name: booking_status, dtype: int64

# %% [markdown]
# Lets recode these to numerical values.
#
# - 0 for not_canceled
# - 1 for canceled

# %%
df['booking_status'] = df['booking_status'].map({'Not_Canceled':0, 'Canceled':1})

# %% [markdown]
# ## Setting up a pipeline

# %%
float_pipe = Pipeline([
    ('ss', StandardScaler())
])

# %%
cat_pipe = Pipeline([
    ('ohe', OneHotEncoder(drop='first', sparse_output=False))
])

# %%
ColTrans = ColumnTransformer(transformers=[
    ('float_pipe', float_pipe, selector(dtype_include=float)),
    ('cat_pipe', cat_pipe, selector(dtype_include=object))
], remainder='passthrough')

# %% [markdown]
# ## Setting up Train/Test Split

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  float64
#  4   no_of_week_nights                     36275 non-null  float64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  float64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
X = df.drop(['Booking_ID', 'booking_status', 'date'], axis=1)
y = df['booking_status']

# %%
# creating initial validation set
X_total, X_val, y_total, y_val = train_test_split(X, 
                                                  y, 
                                                  test_size=.2, 
                                                  random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_total, 
                                                    y_total,
                                                    test_size=.2,
                                                    random_state=42)

# %% [markdown]
# ### Creating Score Cards to Keep Track of Results

# %%
score_card = pd.DataFrame(columns=['Name', 'Accuracy', 'Precision', 'Recall', 
                                   'F1 Score', 'ROC/AUC Score'])

cv_score_card = pd.DataFrame(columns=['Name', 'Train Accuracy', 'Test Accuracy',
                                      'Train Precision', 'Test Precision',
                                      'Train Recall', 'Test Recall',
                                      'Train F1 Score', 'Test F1 Score',
                                      'Train ROC/AUC Score', 'Test ROC/AUC Score'])

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Dummy Model

# %%
dummy_model = Pipeline([
    ('ColTrans', ColTrans),
    ('dummy', DummyClassifier(strategy='most_frequent', random_state=42))
])

# %%
dummy_model = DummyClassifier(strategy='most_frequent', random_state=42)

# %%
score_card = score_model(dummy_model, 
                         'Dummy Model',
                         score_card,
                         X_train,
                         X_test,
                         y_train,
                         y_test)

# %%
score_card
# Out:
#           Name  Accuracy  Precision  Recall  F1 Score  ROC/AUC Score
# 0  Dummy Model  0.668332        0.0     0.0       0.0            0.5

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.668332
# 1    0.331668
# Name: booking_status, dtype: float64

# %% [markdown]
# OK, dummy model is predicting as expected. Let's try some other models.

# %% [markdown]
# ## Logistic Regression

# %%
log_reg = Pipeline([
    ('ColTrans', ColTrans),
    ('logreg', LogisticRegression(random_state=42))
])

# %% [markdown]
# ### Base Model

# %%
score_card = score_model(log_reg, 
                        'Logistic Regression Base',
                        score_card,
                        X_train,
                        X_test,
                        y_train,
                        y_test)

# %%
score_card
# Out:
#                        Name  Accuracy  Precision    Recall  F1 Score  \
# 0               Dummy Model  0.668332   0.000000  0.000000  0.000000
# 1  Logistic Regression Base  0.797553   0.733209  0.612468  0.667421
#
#    ROC/AUC Score
# 0       0.500000
# 1       0.750936

# %%
cv_score_card = cv_score(log_reg,
                        'Logistic Regression Base',
                        cv_score_card,
                        X_train,
                        y_train)

# %%
cv_score_card
# Out:
#                        Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  Logistic Regression Base        0.798673       0.799492         0.729419
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0         0.73231      0.604785     0.603527        0.661279       0.661486
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.854213            0.853841    False

# %% [markdown]
# ### Logistic Regression GridSearch 1

# %%
lr_params = {
    'logreg__solver': ['lbfgs', 'lbfgs', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
    'logreg__fit_intercept':[True, False]
}
lr_gs1 = GridSearchCV(estimator=log_reg, 
                     param_grid=lr_params,
                     scoring='f1',
                     cv=5, 
                     verbose=1,
                     n_jobs=2)

lr_gs1.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
lr_gs1.best_score_
# Out:
# 0.6725554862343748

# %%
lr_gs1.best_params_
# Out:
# {'logreg__fit_intercept': True, 'logreg__solver': 'newton-cg'}

# %% [markdown]
# ### Logistic Regression GridSearch 2

# %%
lr_params = {
    'logreg__solver': ['newton-cg'],
    'logreg__fit_intercept':[True],
    'logreg__max_iter':[100, 200, 300, 400],
    'logreg__penalty':[None, 'l2']
}
lr_gs2 = GridSearchCV(estimator=log_reg, 
                     param_grid=lr_params,
                     scoring='f1',
                     cv=5, 
                     verbose=1,
                     n_jobs=2)

lr_gs2.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits

# %%
lr_gs2.best_score_
# Out:
# 0.6733841294526293

# %%
lr_gs2.best_params_
# Out:
# {'logreg__fit_intercept': True,
#  'logreg__max_iter': 100,
#  'logreg__penalty': None,
#  'logreg__solver': 'newton-cg'}

# %% [markdown]
# ### Updating Score Card

# %%
# updating for GS1
cv_score_card = cv_score(lr_gs1.best_estimator_,
                         'Logistic Regression GS1',
                         cv_score_card,
                         X_train,
                         y_train,
                         n_jobs=2)

# %%
# updating for GS2
cv_score_card = cv_score(lr_gs2.best_estimator_,
                         'Logistic Regression GS2',
                         cv_score_card,
                         X_train,
                         y_train,
                         n_jobs=2)

# %%
cv_score_card
# Out:
#                        Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  Logistic Regression Base        0.798673       0.799492         0.729419
# 1   Logistic Regression GS1        0.804424       0.803670         0.734888
# 2   Logistic Regression GS2        0.804198       0.804187         0.734889
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.732310      0.604785     0.603527        0.661279       0.661486
# 1        0.734054      0.622813     0.620758        0.674222       0.672555
# 2        0.735074      0.621719     0.621421        0.673581       0.673384
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.854213            0.853841    False
# 1             0.862443            0.861645    False
# 2             0.862274            0.861519    False

# %% [markdown]
# ## SVC

# %% [markdown]
# ### Base Model

# %%
SVC_model = Pipeline([
    ('ColTrans', ColTrans),
    ('svc', SVC(random_state=42))
])

# %%
score_card = score_model(SVC_model, 
                         'SVC Base',
                         score_card,
                         X_train,
                         X_test,
                         y_train,
                         y_test)

# %%
score_card
# Out:
#                        Name  Accuracy  Precision    Recall  F1 Score  \
# 0               Dummy Model  0.668332   0.000000  0.000000  0.000000
# 1  Logistic Regression Base  0.797553   0.733209  0.612468  0.667421
# 2                  SVC Base  0.668332   0.000000  0.000000  0.000000
#
#    ROC/AUC Score
# 0       0.500000
# 1       0.750936
# 2       0.500000

# %% [markdown]
# SVC Doesnt work well. Need to troubleshoot and see what's up.

# %%
cv_score_card = cv_score(SVC_model,
                         'SVC Base',
                         cv_score_card,
                         X_train,
                         y_train,
                         n_jobs=3)

# %%
cv_score_card
# Out:
#                        Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  Logistic Regression Base        0.798673       0.799492         0.729419
# 1   Logistic Regression GS1        0.804424       0.803670         0.734888
# 2   Logistic Regression GS2        0.804198       0.804187         0.734889
# 3                  SVC Base        0.675052       0.675052         0.000000
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.732310      0.604785     0.603527        0.661279       0.661486
# 1        0.734054      0.622813     0.620758        0.674222       0.672555
# 2        0.735074      0.621719     0.621421        0.673581       0.673384
# 3        0.000000      0.000000     0.000000        0.000000       0.000000
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.854213            0.853841    False
# 1             0.862443            0.861645    False
# ...

# %% [markdown]
# ### SVC Gridsearch 1

# %%
svc_params = {
    'svc__kernel':['linear', 'poly', 'rbf', 'sigmoid']
}

svc_gs1 = GridSearchCV(SVC_model,
                      param_grid=svc_params,
                      cv=5,
                      scoring='f1',
                      verbose=1,
                      n_jobs=3)

svc_gs1.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits

# %%
svc_gs1.best_params_
# Out:
# {'svc__kernel': 'linear'}

# %%
svc_gs1.best_score_
# Out:
# 0.6737330375147892

# %%
svc_gs1.cv_results_
# Out:
# {'mean_fit_time': array([4.01273913, 4.6610218 , 5.85548029, 7.56458049]),
#  'std_fit_time': array([0.30280461, 0.04651301, 0.04804844, 0.07139605]),
#  'mean_score_time': array([0.3905551 , 0.88549871, 2.82586102, 1.63599048]),
#  'std_score_time': array([0.00701188, 0.0107124 , 0.043858  , 0.02872331]),
#  'param_svc__kernel': masked_array(data=['linear', 'poly', 'rbf', 'sigmoid'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'svc__kernel': 'linear'},
#   {'svc__kernel': 'poly'},
#   {'svc__kernel': 'rbf'},
#   {'svc__kernel': 'sigmoid'}],
#  'split0_test_score': array([0.66619569, 0.        , 0.        , 0.        ]),
#  'split1_test_score': array([0.68226257, 0.        , 0.        , 0.        ]),
#  'split2_test_score': array([0.66737892, 0.        , 0.        , 0.        ]),
#  'split3_test_score': array([0.67525958, 0.        , 0.        , 0.        ]),
# ...

# %% [markdown]
# The linear model is the only one that performed well at all. Lets try another attempt at GS.

# %% [markdown]
# ### SVC GridSearch 2

# %%
svc_params2 = {
    'svc__kernel':['linear'],
    'svc__shrinking':[True, False],
    'svc__class_weight':['balanced', None]
}

svc_gs2 = GridSearchCV(SVC_model,
                       param_grid=svc_params2,
                       cv=5,
                       scoring='f1',
                       verbose=1,
                       n_jobs=3)

svc_gs2.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits

# %%
svc_gs2.best_params_
# Out:
# {'svc__class_weight': 'balanced',
#  'svc__kernel': 'linear',
#  'svc__shrinking': False}

# %%
svc_gs2.best_score_
# Out:
# 0.6973966576684189

# %% [markdown]
# ### Updating Score Card

# %%
# updating for GS1
cv_score_card = cv_score(svc_gs1.best_estimator_,
                         'SVM GS1',
                         cv_score_card,
                         X_train,
                         y_train,
                         n_jobs=3)

# %%
# updating for gs2
cv_score_card = cv_score(svc_gs2.best_estimator_,
                         'SVM GS2',
                         cv_score_card,
                         X_train,
                         y_train,
                         n_jobs=3)

# %%
cv_score_card
# Out:
#                        Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  Logistic Regression Base        0.798673       0.799492         0.729419
# 1   Logistic Regression GS1        0.804424       0.803670         0.734888
# 2   Logistic Regression GS2        0.804198       0.804187         0.734889
# 3                  SVC Base        0.675052       0.675052         0.000000
# 4                   SVM GS1        0.801850       0.801732         0.723538
# 5                   SVM GS2        0.775327       0.775930         0.620955
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.732310      0.604785     0.603527        0.661279       0.661486
# 1        0.734054      0.622813     0.620758        0.674222       0.672555
# 2        0.735074      0.621719     0.621421        0.673581       0.673384
# 3        0.000000      0.000000     0.000000        0.000000       0.000000
# ...

# %% [markdown]
# ## NuSVC

# %% [markdown]
# ### Base Model

# %%
NuSVC_model = Pipeline([
    ('ColTrans', ColTrans),
    ('nusvc', NuSVC(random_state=42))
])

# %%
score_card = score_model(NuSVC_model, 
                         'NuSVC Base',
                         score_card,
                         X_train,
                         X_test,
                         y_train,
                         y_test)

# %%
score_card
# Out:
#                        Name  Accuracy  Precision    Recall  F1 Score  \
# 0               Dummy Model  0.668332   0.000000  0.000000  0.000000
# 1  Logistic Regression Base  0.797553   0.733209  0.612468  0.667421
# 2                  SVC Base  0.668332   0.000000  0.000000  0.000000
# 3                NuSVC Base  0.753790   0.589855  0.845714  0.694984
#
#    ROC/AUC Score
# 0       0.500000
# 1       0.750936
# 2       0.500000
# 3       0.776943

# %% [markdown]
# Surprisingly, untuned NuSVC performs much better than untuned standard SVC.

# %%
cv_score_card = cv_score(NuSVC_model,
                         'NuSVC Base',
                         cv_score_card,
                         X_train,
                         y_train,
                         n_jobs=3)

# %%
cv_score_card
# Out:
#                        Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  Logistic Regression Base        0.798673       0.799492         0.729419
# 1   Logistic Regression GS1        0.804424       0.803670         0.734888
# 2   Logistic Regression GS2        0.804198       0.804187         0.734889
# 3                  SVC Base        0.675052       0.675052         0.000000
# 4                   SVM GS1        0.801850       0.801732         0.723538
# 5                   SVM GS2        0.775327       0.775930         0.620955
# 6                NuSVC Base        0.732695       0.734665         0.553291
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.732310      0.604785     0.603527        0.661279       0.661486
# 1        0.734054      0.622813     0.620758        0.674222       0.672555
# 2        0.735074      0.621719     0.621421        0.673581       0.673384
# ...

# %% [markdown]
# ### NuSVC GridSearch 1

# %%
nusvc_params = {
    'nusvc__nu': [.25, .5, .75],
    'nusvc__kernel':['linear', 'poly', 'rbf', 'sigmoid']
}

# %%
nusvc_gs1 = GridSearchCV(NuSVC_model,
                        param_grid=nusvc_params,
                        cv=5,
                        scoring='f1',
                        verbose=1,
                        n_jobs=4)

nusvc_gs1.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
nusvc_gs1.best_params_
# Out:
# {'nusvc__kernel': 'poly', 'nusvc__nu': 0.5}

# %%
nusvc_gs1.best_score_
# Out:
# 0.6704109440821973

# %% [markdown]
# ### NuSVC GridSearch 2

# %%
nusvc_params2 = {
    'nusvc__nu': [.5],
    'nusvc__kernel':['poly'],
    'nusvc__degree': [1, 2, 3],
    'nusvc__shrinking':[True, False],
    'nusvc__class_weight':['balanced', None]
}

# %%
nusvc_gs2 = GridSearchCV(NuSVC_model,
                        param_grid=nusvc_params2,
                        cv=5,
                        scoring='f1',
                        verbose=1,
                        n_jobs=4)

nusvc_gs2.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
nusvc_gs2.best_params_
# Out:
# {'nusvc__class_weight': 'balanced',
#  'nusvc__degree': 3,
#  'nusvc__kernel': 'poly',
#  'nusvc__nu': 0.5,
#  'nusvc__shrinking': True}

# %%
nusvc_gs2.best_score_
# Out:
# 0.6704109440821973

# %% [markdown]
# ### Updating Score Card

# %%
# updating GS 1
cv_score_card = cv_score(nusvc_gs1.best_estimator_, 
                         'NuSVC GS1',
                         cv_score_card,
                         X_train,
                         y_train,
                         n_jobs=3)

# %%
# updating GS 2
cv_score_card = cv_score(nusvc_gs2.best_estimator_, 
                         'NuSVC GS2',
                         cv_score_card,
                         X_train,
                         y_train,
                         n_jobs=3)

# %%
cv_score_card
# Out:
#                        Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  Logistic Regression Base        0.798673       0.799492         0.729419
# 1   Logistic Regression GS1        0.804424       0.803670         0.734888
# 2   Logistic Regression GS2        0.804198       0.804187         0.734889
# 3                  SVC Base        0.675052       0.675052         0.000000
# 4                   SVM GS1        0.801850       0.801732         0.723538
# 5                   SVM GS2        0.775327       0.775930         0.620955
# 6                NuSVC Base        0.732695       0.734665         0.553291
# 7                 NuSVC GS1        0.784685       0.783384         0.680323
# 8                 NuSVC GS2        0.784685       0.783384         0.680323
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.732310      0.604785     0.603527        0.661279       0.661486
# ...

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### Base Model

# %%
DT_model = Pipeline([
    ('ColTrans', ColTrans),
    ('DT', DecisionTreeClassifier(random_state=42))
])

# %%
score_card = score_model(DT_model, 
                         'Decision Tree Base',
                         score_card,
                         X_train,
                         X_test,
                         y_train,
                         y_test)

# %%
score_card
# Out:
#                        Name  Accuracy  Precision    Recall  F1 Score  \
# 0               Dummy Model  0.668332   0.000000  0.000000  0.000000
# 1  Logistic Regression Base  0.797553   0.733209  0.612468  0.667421
# 2                  SVC Base  0.668332   0.000000  0.000000  0.000000
# 3                NuSVC Base  0.753790   0.589855  0.845714  0.694984
# 4        Decision Tree Base  0.865438   0.798851  0.794286  0.796562
#
#    ROC/AUC Score
# 0       0.500000
# 1       0.750936
# 2       0.500000
# 3       0.776943
# 4       0.847517

# %%
cv_score_card = cv_score(DT_model,
                         'Decision Tree Base',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
cv_score_card
# Out:
#                        Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  Logistic Regression Base        0.798673       0.799492         0.729419
# 1   Logistic Regression GS1        0.804424       0.803670         0.734888
# 2   Logistic Regression GS2        0.804198       0.804187         0.734889
# 3                  SVC Base        0.675052       0.675052         0.000000
# 4                   SVM GS1        0.801850       0.801732         0.723538
# 5                   SVM GS2        0.775327       0.775930         0.620955
# 6                NuSVC Base        0.732695       0.734665         0.553291
# 7                 NuSVC GS1        0.784685       0.783384         0.680323
# 8                 NuSVC GS2        0.784685       0.783384         0.680323
# 9        Decision Tree Base        0.994853       0.858718         0.997054
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# ...

# %% [markdown]
# ### Reducing Overfitting

# %%
DT_score_card = pd.DataFrame(columns=['Name', 'Train Accuracy', 'Test Accuracy',
                                      'Train Precision', 'Test Precision',
                                      'Train Recall', 'Test Recall',
                                      'Train F1 Score', 'Test F1 Score',
                                      'Train ROC/AUC Score', 'Test ROC/AUC Score'])

# %%
# Base
DT_model_depth = Pipeline([
    ('ColTrans', ColTrans),
    ('DT', DecisionTreeClassifier(random_state=42
                                 ))
])

DT_score_card = cv_score(DT_model_depth, 
                         'Decision Tree Base',
                         DT_score_card,
                         X_train,
                         y_train)

DT_score_card
# Out:
#                  Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  Decision Tree Base        0.994853       0.858718         0.997054
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.777288      0.987076     0.792416         0.99204       0.784706
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0              0.99991            0.843314     True

# %%
# Max Depth 5
DT_model_depth5 = Pipeline([
    ('ColTrans', ColTrans),
    ('DT', DecisionTreeClassifier(random_state=42,
                                  max_depth=5))
])

DT_score_card = cv_score(DT_model_depth5, 
                         'Decision Tree Max Depth = 5',
                         DT_score_card,
                         X_train,
                         y_train)

DT_score_card
# Out:
#                           Name  Train Accuracy  Test Accuracy  \
# 0           Decision Tree Base        0.994853       0.858718
# 1  Decision Tree Max Depth = 5        0.834575       0.832529
#
#    Train Precision  Test Precision  Train Recall  Test Recall  Train F1 Score  \
# 0         0.997054        0.777288      0.987076     0.792416        0.992040
# 1         0.764397        0.760808      0.710034     0.707317        0.736074
#
#    Test F1 Score  Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0       0.784706             0.999910            0.843314     True
# 1       0.732843             0.884822            0.880009    False

# %%
# Max Depth 9
DT_model_depth9 = Pipeline([
    ('ColTrans', ColTrans),
    ('DT', DecisionTreeClassifier(random_state=42,
                                  max_depth=9))
])

DT_score_card = cv_score(DT_model_depth9, 
                         'Decision Tree Max Depth = 9',
                         DT_score_card,
                         X_train,
                         y_train)

DT_score_card
# Out:
#                           Name  Train Accuracy  Test Accuracy  \
# 0           Decision Tree Base        0.994853       0.858718
# 1  Decision Tree Max Depth = 5        0.834575       0.832529
# 2  Decision Tree Max Depth = 9        0.880858       0.865696
#
#    Train Precision  Test Precision  Train Recall  Test Recall  Train F1 Score  \
# 0         0.997054        0.777288      0.987076     0.792416        0.992040
# 1         0.764397        0.760808      0.710034     0.707317        0.736074
# 2         0.847998        0.820975      0.772733     0.751458        0.808206
#
#    Test F1 Score  Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0       0.784706             0.999910            0.843314     True
# 1       0.732843             0.884822            0.880009    False
# 2       0.783880             0.939874            0.918931    False

# %%
# Max Depth 10
DT_model_depth10 = Pipeline([
    ('ColTrans', ColTrans),
    ('DT', DecisionTreeClassifier(random_state=42,
                                  max_depth=10))
])

DT_score_card = cv_score(DT_model_depth10, 
                         'Decision Tree Max Depth = 10',
                         DT_score_card,
                         X_train,
                         y_train)

DT_score_card
# Out:
#                            Name  Train Accuracy  Test Accuracy  \
# 0            Decision Tree Base        0.994853       0.858718
# 1   Decision Tree Max Depth = 5        0.834575       0.832529
# 2   Decision Tree Max Depth = 9        0.880858       0.865696
# 3  Decision Tree Max Depth = 10        0.891282       0.870004
#
#    Train Precision  Test Precision  Train Recall  Test Recall  Train F1 Score  \
# 0         0.997054        0.777288      0.987076     0.792416        0.992040
# 1         0.764397        0.760808      0.710034     0.707317        0.736074
# 2         0.847998        0.820975      0.772733     0.751458        0.808206
# 3         0.860821        0.822305      0.794041     0.765510        0.825957
#
#    Test F1 Score  Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0       0.784706             0.999910            0.843314     True
# 1       0.732843             0.884822            0.880009    False
# ...

# %% [markdown]
# Based on the performance of the untuned Decision Tree with varying max depth, I will employ gridsearch using a max depth of 9.

# %%
cv_score_card = cv_score(DT_model_depth9, 
                         'Decision Tree Max Depth = 9',
                         cv_score_card,
                         X_train,
                         y_train)

# %% [markdown]
# ### Decision Tree GridSearch 1

# %%
DT_params1 = {
    'DT__criterion': ['gini', 'entropy', 'log_loss'],
    'DT__min_samples_split':[.5, 2, 3, 4],
    'DT__max_depth': [9]
}

# %%
DT_gs1 = GridSearchCV(DT_model,
                      param_grid=DT_params1,
                      cv=5,
                      scoring='f1',
                      verbose=1,
                      n_jobs=2)

DT_gs1.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
DT_gs1.best_params_
# Out:
# {'DT__criterion': 'gini', 'DT__max_depth': 9, 'DT__min_samples_split': 2}

# %%
DT_gs1.best_score_
# Out:
# 0.7838796890383162

# %% [markdown]
# ### Decision Tree GridSearch 2

# %%
DT_params2 = {
    'DT__criterion': ['gini'],
    'DT__min_samples_split':[2],
    'DT__max_depth': [9],
    'DT__min_samples_leaf': [1, 2, 3, 4],
    'DT__max_features':[None, 'sqrt', 'log2'],
    'DT__class_weight':['balanced', None]
}

# %%
DT_gs2 = GridSearchCV(DT_model,
                      param_grid=DT_params2,
                      cv=5,
                      scoring='f1',
                      verbose=1,
                      n_jobs=2)

DT_gs2.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits

# %%
DT_gs2.best_params_
# Out:
# {'DT__class_weight': None,
#  'DT__criterion': 'gini',
#  'DT__max_depth': 9,
#  'DT__max_features': None,
#  'DT__min_samples_leaf': 1,
#  'DT__min_samples_split': 2}

# %%
DT_gs2.best_score_
# Out:
# 0.7838796890383162

# %% [markdown]
# ### Updating Score Card

# %%
# updating GS 1
cv_score_card = cv_score(DT_gs1.best_estimator_, 
                         'Decision Tree GS1',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
# updating GS 2
cv_score_card = cv_score(DT_gs2.best_estimator_, 
                         'Decision Tree GS2',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
cv_score_card
# Out:
#                            Name  Train Accuracy  Test Accuracy  \
# 0      Logistic Regression Base        0.798673       0.799492
# 1       Logistic Regression GS1        0.804424       0.803670
# 2       Logistic Regression GS2        0.804198       0.804187
# 3                      SVC Base        0.675052       0.675052
# 4                       SVM GS1        0.801850       0.801732
# 5                       SVM GS2        0.775327       0.775930
# 6                    NuSVC Base        0.732695       0.734665
# 7                     NuSVC GS1        0.784685       0.783384
# 8                     NuSVC GS2        0.784685       0.783384
# 9            Decision Tree Base        0.994853       0.858718
# 10  Decision Tree Max Depth = 9        0.880858       0.865696
# 11            Decision Tree GS1        0.880858       0.865696
# 12            Decision Tree GS2        0.880858       0.865696
#
#     Train Precision  Test Precision  Train Recall  Test Recall  \
# ...

# %% [markdown]
# ## Random Forest Model

# %%
RF_model = Pipeline([
    ('ColTrans', ColTrans),
    ('RF', RandomForestClassifier(random_state=42))
])

# %%
score_card = score_model(RF_model, 
                         'Random Forest Base',
                         score_card,
                         X_train,
                         X_test,
                         y_train,
                         y_test)

# %%
score_card
# Out:
#                        Name  Accuracy  Precision    Recall  F1 Score  \
# 0               Dummy Model  0.668332   0.000000  0.000000  0.000000
# 1  Logistic Regression Base  0.797553   0.733209  0.612468  0.667421
# 2                  SVC Base  0.668332   0.000000  0.000000  0.000000
# 3                NuSVC Base  0.753790   0.589855  0.845714  0.694984
# 4        Decision Tree Base  0.865438   0.798851  0.794286  0.796562
# 5        Random Forest Base  0.894728   0.876289  0.794805  0.833560
#
#    ROC/AUC Score
# 0       0.500000
# 1       0.750936
# 2       0.500000
# 3       0.776943
# 4       0.847517
# 5       0.869560

# %%
cv_score_card = cv_score(RF_model,
                         'Random Forest Base',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
cv_score_card
# Out:
#                            Name  Train Accuracy  Test Accuracy  \
# 0      Logistic Regression Base        0.798673       0.799492
# 1       Logistic Regression GS1        0.804424       0.803670
# 2       Logistic Regression GS2        0.804198       0.804187
# 3                      SVC Base        0.675052       0.675052
# 4                       SVM GS1        0.801850       0.801732
# 5                       SVM GS2        0.775327       0.775930
# 6                    NuSVC Base        0.732695       0.734665
# 7                     NuSVC GS1        0.784685       0.783384
# 8                     NuSVC GS2        0.784685       0.783384
# 9            Decision Tree Base        0.994853       0.858718
# 10  Decision Tree Max Depth = 9        0.880858       0.865696
# 11            Decision Tree GS1        0.880858       0.865696
# 12            Decision Tree GS2        0.880858       0.865696
# 13           Random Forest Base        0.994853       0.895245
#
# ...

# %% [markdown]
# ### Reducing Overfitting

# %%
RF_score_card = pd.DataFrame(columns=['Name', 'Train Accuracy', 'Test Accuracy',
                                      'Train Precision', 'Test Precision',
                                      'Train Recall', 'Test Recall',
                                      'Train F1 Score', 'Test F1 Score',
                                      'Train ROC/AUC Score', 'Test ROC/AUC Score'])

# %%
# Base
RF_Model_depth = Pipeline([
    ('ColTrans', ColTrans),
    ('RF', RandomForestClassifier(random_state=42,
#                                   max_depth=5
                                 ))
])

RF_score_card = cv_score(RF_Model_depth, 
                         'Random Forest Base',
                         RF_score_card,
                         X_train,
                         y_train)

RF_score_card
# Out:
#                  Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  Random Forest Base        0.994853       0.895245         0.996158
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.870973      0.987971      0.79573        0.992047       0.831523
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.999364            0.945935     True

# %%
# Max Depth 5
RF_Model_depth5 = Pipeline([
    ('ColTrans', ColTrans),
    ('RF', RandomForestClassifier(random_state=42,
                                  max_depth=5
                                 ))
])

RF_score_card = cv_score(RF_Model_depth5, 
                         'Random Forest Depth = 5',
                         RF_score_card,
                         X_train,
                         y_train)

RF_score_card
# Out:
#                       Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0       Random Forest Base        0.994853       0.895245         0.996158
# 1  Random Forest Depth = 5        0.818875       0.815644         0.905035
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.870973      0.987971      0.79573        0.992047       0.831523
# 1        0.898930      0.494798      0.48780        0.639452       0.631570
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.999364            0.945935     True
# 1             0.889227            0.885078    False

# %%
# Max Depth 10
RF_Model_depth10 = Pipeline([
    ('ColTrans', ColTrans),
    ('RF', RandomForestClassifier(random_state=42,
                                  max_depth=10
                                 ))
])

RF_score_card = cv_score(RF_Model_depth10, 
                         'Random Forest Depth = 10',
                         RF_score_card,
                         X_train,
                         y_train)

RF_score_card
# Out:
#                        Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0        Random Forest Base        0.994853       0.895245         0.996158
# 1   Random Forest Depth = 5        0.818875       0.815644         0.905035
# 2  Random Forest Depth = 10        0.888837       0.874009         0.880045
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.870973      0.987971     0.795730        0.992047       0.831523
# 1        0.898930      0.494798     0.487800        0.639452       0.631570
# 2        0.856582      0.761830     0.735683        0.816635       0.791278
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.999364            0.945935     True
# 1             0.889227            0.885078    False
# 2             0.948558            0.927517    False

# %%
# Max Depth 11
RF_Model_depth11 = Pipeline([
    ('ColTrans', ColTrans),
    ('RF', RandomForestClassifier(random_state=42,
                                  max_depth=11
                                 ))
])

RF_score_card = cv_score(RF_Model_depth11, 
                         'Random Forest Depth = 11',
                         RF_score_card,
                         X_train,
                         y_train)

RF_score_card
# Out:
#                        Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0        Random Forest Base        0.994853       0.895245         0.996158
# 1   Random Forest Depth = 5        0.818875       0.815644         0.905035
# 2  Random Forest Depth = 10        0.888837       0.874009         0.880045
# 3  Random Forest Depth = 11        0.895503       0.878360         0.885113
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.870973      0.987971     0.795730        0.992047       0.831523
# 1        0.898930      0.494798     0.487800        0.639452       0.631570
# 2        0.856582      0.761830     0.735683        0.816635       0.791278
# 3        0.858974      0.779626     0.748672        0.829020       0.799843
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.999364            0.945935     True
# 1             0.889227            0.885078    False
# ...

# %% [markdown]
# Based on the performance of the untuned Random Forest with varying max depth, I will employ gridsearch using a max depth of 10.

# %%
cv_score_card = cv_score(RF_Model_depth10, 
                         'Random Forest Max Depth = 10',
                         cv_score_card,
                         X_train,
                         y_train)

# %% [markdown]
# ### Random Forest GridSearch 1

# %%
rf_params = {
    'RF__max_depth': [10],
    'RF__criterion': ['gini', 'log_loss', 'entropy'],
    'RF__class_weight':[None, 'balanced'],
    'RF__max_samples':[None, .5, .75]
}

# %%
rf_gs1 = GridSearchCV(RF_model,
                      param_grid=rf_params,
                      cv=5,
                      scoring='f1',
                      verbose=1,
                      n_jobs=2)

rf_gs1.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits

# %%
rf_gs1.best_params_
# Out:
# {'RF__class_weight': 'balanced',
#  'RF__criterion': 'gini',
#  'RF__max_depth': 10,
#  'RF__max_samples': 0.75}

# %%
rf_gs1.best_score_
# Out:
# 0.7999457009970449

# %% [markdown]
# ### Random Forest GridSearch 2

# %%
rf_params2 = {
    'RF__max_depth': [10],
    'RF__criterion': ['gini'],
    'RF__class_weight':['balanced'],
    'RF__max_samples':[.75],
    'RF__n_estimators': np.arange(10, 201, 10)
}

# %%
rf_gs2 = GridSearchCV(RF_model,
                      param_grid=rf_params2,
                      cv=5,
                      scoring='f1',
                      verbose=1,
                      n_jobs=2)

rf_gs2.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits

# %%
rf_gs2.best_params_
# Out:
# {'RF__class_weight': 'balanced',
#  'RF__criterion': 'gini',
#  'RF__max_depth': 10,
#  'RF__max_samples': 0.75,
#  'RF__n_estimators': 70}

# %%
rf_gs2.best_score_
# Out:
# 0.8006640402666593

# %% [markdown]
# ### Updating Score Card

# %%
# updating GS 1
cv_score_card = cv_score(rf_gs1.best_estimator_, 
                         'Random Forest GS1',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
# updating GS 2
cv_score_card = cv_score(rf_gs2.best_estimator_, 
                         'Random Forest GS2',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
cv_score_card
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression Base        0.798673       0.799492
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 3                       SVC Base        0.675052       0.675052
# 4                        SVM GS1        0.801850       0.801732
# 5                        SVM GS2        0.775327       0.775930
# 6                     NuSVC Base        0.732695       0.734665
# 7                      NuSVC GS1        0.784685       0.783384
# 8                      NuSVC GS2        0.784685       0.783384
# 9             Decision Tree Base        0.994853       0.858718
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 11             Decision Tree GS1        0.880858       0.865696
# 12             Decision Tree GS2        0.880858       0.865696
# 13            Random Forest Base        0.994853       0.895245
# ...

# %% [markdown]
# ### Determining Feature Importance

# %% [markdown]
# To get a better idea of which features are truly the most important for predicting the likelihood of cancellation, I will extract feature importance from my Random Forest Model.

# %%
# Giving the best estimator a variable name
best_estimator = rf_gs2.best_estimator_

# fitting to data again
best_estimator.fit(X_train, y_train);

# %%
# assigning importance to variable
importance = best_estimator[1].feature_importances_

# %%
# feature names in
names_in = best_estimator.feature_names_in_

# %%
# getting all steps from col transformer
col_trans = best_estimator.named_steps['ColTrans']

# %%
# getting the float pipe feature names
float_names = col_trans.transformers_[0][2].copy()

# %%
# getting cat pipe feature names
cat_names = col_trans.named_transformers_['cat_pipe'].named_steps['ohe'].get_feature_names_out()

# %%
# getting the remaining indices that are moved through the pipe
remainder_indices = col_trans.transformers_[2][2]

# matching the indices with the original names in
remainder_names = list(names_in[remainder_indices])

# %%
# adding the names in the order of the pipeline
float_names.extend(list(cat_names))

float_names.extend(list(remainder_names))

# %%
# creating a df of the features and their importance
importance_df = pd.DataFrame(list(zip(float_names, 
                                      importance)), columns=['Feature', 'Importance'])



# rearranging df for clarity 
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# top 10 results and cleaning
importance_df = importance_df.head(10).reset_index().drop('index', axis=1)

# %%
importance_df
# Out:
#                        Feature  Importance
# 0                    lead_time    0.333635
# 1       no_of_special_requests    0.172753
# 2           avg_price_per_room    0.087862
# 3             total_stay_price    0.061644
# 4                arrival_month    0.060427
# 5   market_segment_type_Online    0.048129
# 6                 arrival_year    0.045918
# 7  market_segment_type_Offline    0.032100
# 8                 arrival_date    0.026605
# 9                   total_stay    0.021137

# %% [markdown]
# We can see that the feature importance aligns well with the initial analysis. The top five important features are:
#
# - `lead_time`
# - `no_of_special_requests`
# - `avg_price_per_room`
# - `total_stay_price`
# - `arrival_month`

# %% [markdown]
# ## K-Nearest Neighbors

# %%
KNN_model = Pipeline([
    ('ColTrans', ColTrans),
    ('knn', KNeighborsClassifier())
])

# %%
score_card = score_model(KNN_model, 
                         'KNN Base',
                         score_card,
                         X_train,
                         X_test,
                         y_train,
                         y_test)

# %%
score_card
# Out:
#                        Name  Accuracy  Precision    Recall  F1 Score  \
# 0               Dummy Model  0.668332   0.000000  0.000000  0.000000
# 1  Logistic Regression Base  0.797553   0.733209  0.612468  0.667421
# 2                  SVC Base  0.668332   0.000000  0.000000  0.000000
# 3                NuSVC Base  0.753790   0.589855  0.845714  0.694984
# 4        Decision Tree Base  0.865438   0.798851  0.794286  0.796562
# 5        Random Forest Base  0.894728   0.876289  0.794805  0.833560
# 6                  KNN Base  0.836492   0.778539  0.708571  0.741909
#
#    ROC/AUC Score
# 0       0.500000
# 1       0.750936
# 2       0.500000
# 3       0.776943
# 4       0.847517
# 5       0.869560
# 6       0.804273

# %%
cv_score_card = cv_score(KNN_model,
                         'KNN Base',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
cv_score_card
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression Base        0.798673       0.799492
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 3                       SVC Base        0.675052       0.675052
# 4                        SVM GS1        0.801850       0.801732
# 5                        SVM GS2        0.775327       0.775930
# 6                     NuSVC Base        0.732695       0.734665
# 7                      NuSVC GS1        0.784685       0.783384
# 8                      NuSVC GS2        0.784685       0.783384
# 9             Decision Tree Base        0.994853       0.858718
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 11             Decision Tree GS1        0.880858       0.865696
# 12             Decision Tree GS2        0.880858       0.865696
# 13            Random Forest Base        0.994853       0.895245
# ...

# %% [markdown]
# ### Reduce Overfitting

# %%
KNN_score_card = pd.DataFrame(columns=['Name', 'Train Accuracy', 'Test Accuracy',
                                      'Train Precision', 'Test Precision',
                                      'Train Recall', 'Test Recall',
                                      'Train F1 Score', 'Test F1 Score',
                                      'Train ROC/AUC Score', 'Test ROC/AUC Score'])

# %%
# Base - neighbors = 5
KNN_Model_neighbors = Pipeline([
    ('ColTrans', ColTrans),
    ('KNN', KNeighborsClassifier(n_neighbors=5,
                                 ))
])

KNN_score_card = cv_score(KNN_Model_neighbors, 
                         'KNN Base (5)',
                         KNN_score_card,
                         X_train,
                         y_train)

KNN_score_card
# Out:
#            Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  KNN Base (5)        0.885952       0.828782         0.853763
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.757809      0.783172     0.695387        0.816943       0.725179
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.951837            0.880021     True

# %%
# neighbors = 10
KNN_Model_neighbors10 = Pipeline([
    ('ColTrans', ColTrans),
    ('KNN', KNeighborsClassifier(n_neighbors=10,
#                                  metric='nan_euclidean'
                                 ))
])

KNN_score_card = cv_score(KNN_Model_neighbors10, 
                         'KNN Neighbors = 10',
                         KNN_score_card,
                         X_train,
                         y_train)

KNN_score_card
# Out:
#                  Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0        KNN Base (5)        0.885952       0.828782         0.853763
# 1  KNN Neighbors = 10        0.857114       0.826197         0.861925
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.757809      0.783172     0.695387        0.816943       0.725179
# 1        0.805862      0.667153     0.612937        0.752131       0.696160
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.951837            0.880021     True
# 1             0.928786            0.883638     True

# %%
# neighbors = 20
KNN_Model_neighbors20 = Pipeline([
    ('ColTrans', ColTrans),
    ('KNN', KNeighborsClassifier(n_neighbors=20,
                                 ))
])

KNN_score_card = cv_score(KNN_Model_neighbors20, 
                         'KNN Neighbors = 20',
                         KNN_score_card,
                         X_train,
                         y_train)

KNN_score_card
# Out:
#                  Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0        KNN Base (5)        0.885952       0.828782         0.853763
# 1  KNN Neighbors = 10        0.857114       0.826197         0.861925
# 2  KNN Neighbors = 20        0.834381       0.815989         0.827953
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.757809      0.783172     0.695387        0.816943       0.725179
# 1        0.805862      0.667153     0.612937        0.752131       0.696160
# 2        0.793728      0.618935     0.586029        0.708339       0.674151
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.951837            0.880021     True
# 1             0.928786            0.883638     True
# 2             0.904869            0.876452     True

# %%
# neighbors = 25
KNN_Model_neighbors25 = Pipeline([
    ('ColTrans', ColTrans),
    ('KNN', KNeighborsClassifier(n_neighbors=25,
                                 ))
])

KNN_score_card = cv_score(KNN_Model_neighbors25, 
                         'KNN Neighbors = 25',
                         KNN_score_card,
                         X_train,
                         y_train)

KNN_score_card
# Out:
#                  Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0        KNN Base (5)        0.885952       0.828782         0.853763
# 1  KNN Neighbors = 10        0.857114       0.826197         0.861925
# 2  KNN Neighbors = 20        0.834381       0.815989         0.827953
# 3  KNN Neighbors = 25        0.830462       0.815730         0.805294
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.757809      0.783172     0.695387        0.816943       0.725179
# 1        0.805862      0.667153     0.612937        0.752131       0.696160
# 2        0.793728      0.618935     0.586029        0.708339       0.674151
# 3        0.780980      0.630799     0.601802        0.707432       0.679706
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.951837            0.880021     True
# 1             0.928786            0.883638     True
# 2             0.904869            0.876452     True
# ...

# %%
# neighbors = 28
KNN_Model_neighbors28 = Pipeline([
    ('ColTrans', ColTrans),
    ('KNN', KNeighborsClassifier(n_neighbors=28,
                                 ))
])

KNN_score_card = cv_score(KNN_Model_neighbors28, 
                         'KNN Neighbors = 28',
                         KNN_score_card,
                         X_train,
                         y_train)

KNN_score_card
# Out:
#                  Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0        KNN Base (5)        0.885952       0.828782         0.853763
# 1  KNN Neighbors = 10        0.857114       0.826197         0.861925
# 2  KNN Neighbors = 20        0.834381       0.815989         0.827953
# 3  KNN Neighbors = 25        0.830462       0.815730         0.805294
# 4  KNN Neighbors = 28        0.825088       0.809442         0.817519
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.757809      0.783172     0.695387        0.816943       0.725179
# 1        0.805862      0.667153     0.612937        0.752131       0.696160
# 2        0.793728      0.618935     0.586029        0.708339       0.674151
# 3        0.780980      0.630799     0.601802        0.707432       0.679706
# 4        0.787522      0.594446     0.566409        0.688334       0.658838
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# ...

# %%
# neighbors = 29
KNN_Model_neighbors29 = Pipeline([
    ('ColTrans', ColTrans),
    ('KNN', KNeighborsClassifier(n_neighbors=29,
                                 ))
])

KNN_score_card = cv_score(KNN_Model_neighbors29, 
                         'KNN Neighbors = 29',
                         KNN_score_card,
                         X_train,
                         y_train)

KNN_score_card
# Out:
#                  Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0        KNN Base (5)        0.885952       0.828782         0.853763
# 1  KNN Neighbors = 10        0.857114       0.826197         0.861925
# 2  KNN Neighbors = 20        0.834381       0.815989         0.827953
# 3  KNN Neighbors = 25        0.830462       0.815730         0.805294
# 4  KNN Neighbors = 28        0.825088       0.809442         0.817519
# 5  KNN Neighbors = 29        0.826251       0.811509         0.802706
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.757809      0.783172     0.695387        0.816943       0.725179
# 1        0.805862      0.667153     0.612937        0.752131       0.696160
# 2        0.793728      0.618935     0.586029        0.708339       0.674151
# 3        0.780980      0.630799     0.601802        0.707432       0.679706
# 4        0.787522      0.594446     0.566409        0.688334       0.658838
# ...

# %% [markdown]
# Picking 29 neighbors

# %%
cv_score_card = cv_score(KNN_Model_neighbors29, 
                         'KNN Neighbors = 29',
                         cv_score_card,
                         X_train,
                         y_train)

# %% [markdown]
# ### KNN Gridsearch 1

# %%
knn_params = {
    'knn__n_neighbors': [29],
    'knn__weights':['uniform', 'distance'],
    'knn__p':[1, 2, 3, 4]
}

knn_gs1 = GridSearchCV(KNN_model,
                       param_grid=knn_params,
                       cv=5,
                       scoring='f1',
                       verbose=1,
                       n_jobs=2)

knn_gs1.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits

# %%
knn_gs1.best_params_
# Out:
# {'knn__n_neighbors': 29, 'knn__p': 1, 'knn__weights': 'distance'}

# %%
knn_gs1.best_score_
# Out:
# 0.7609420828463295

# %% [markdown]
# ### KNN Gridsearch 2

# %%
knn_params2 = {
    'knn__n_neighbors': [40],
    'knn__weights':['distance'],
    'knn__p':[1],
    'knn__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}

knn_gs2 = GridSearchCV(KNN_model,
                       param_grid=knn_params2,
                       cv=5,
                       scoring='f1',
                       verbose=1,
                       n_jobs=2)

knn_gs2.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits

# %%
knn_gs2.best_params_
# Out:
# {'knn__algorithm': 'auto',
#  'knn__n_neighbors': 40,
#  'knn__p': 1,
#  'knn__weights': 'distance'}

# %%
knn_gs2.best_score_
# Out:
# 0.7570400857465704

# %% [markdown]
# ### Updating Scorecard

# %%
# updating GS 1
cv_score_card = cv_score(knn_gs1.best_estimator_, 
                         'KNN GS1',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
# updating GS 2
cv_score_card = cv_score(knn_gs2.best_estimator_, 
                         'KNN GS2',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
cv_score_card
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression Base        0.798673       0.799492
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 3                       SVC Base        0.675052       0.675052
# 4                        SVM GS1        0.801850       0.801732
# 5                        SVM GS2        0.775327       0.775930
# 6                     NuSVC Base        0.732695       0.734665
# 7                      NuSVC GS1        0.784685       0.783384
# 8                      NuSVC GS2        0.784685       0.783384
# 9             Decision Tree Base        0.994853       0.858718
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 11             Decision Tree GS1        0.880858       0.865696
# 12             Decision Tree GS2        0.880858       0.865696
# 13            Random Forest Base        0.994853       0.895245
# ...

# %% [markdown]
# KNN gridsearch makes it overfit.

# %% [markdown]
# ## Naive Bayes - Bernoulli

# %%
bernoulli_model = Pipeline([
    ('ColTrans', ColTrans),
    ('bernoulli', BernoulliNB())
])

# %%
score_card = score_model(bernoulli_model, 
                         'Bernoulli Base',
                         score_card,
                         X_train,
                         X_test,
                         y_train,
                         y_test)

# %%
score_card
# Out:
#                        Name  Accuracy  Precision    Recall  F1 Score  \
# 0               Dummy Model  0.668332   0.000000  0.000000  0.000000
# 1  Logistic Regression Base  0.797553   0.733209  0.612468  0.667421
# 2                  SVC Base  0.668332   0.000000  0.000000  0.000000
# 3                NuSVC Base  0.753790   0.589855  0.845714  0.694984
# 4        Decision Tree Base  0.865438   0.798851  0.794286  0.796562
# 5        Random Forest Base  0.894728   0.876289  0.794805  0.833560
# 6                  KNN Base  0.836492   0.778539  0.708571  0.741909
# 7            Bernoulli Base  0.746210   0.632474  0.560519  0.594327
#
#    ROC/AUC Score
# 0       0.500000
# 1       0.750936
# 2       0.500000
# 3       0.776943
# 4       0.847517
# 5       0.869560
# 6       0.804273
# 7       0.699440

# %%
cv_score_card = cv_score(bernoulli_model,
                        'Bernoulli Base',
                        cv_score_card,
                        X_train,
                        y_train)

# %%
cv_score_card
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression Base        0.798673       0.799492
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 3                       SVC Base        0.675052       0.675052
# 4                        SVM GS1        0.801850       0.801732
# 5                        SVM GS2        0.775327       0.775930
# 6                     NuSVC Base        0.732695       0.734665
# 7                      NuSVC GS1        0.784685       0.783384
# 8                      NuSVC GS2        0.784685       0.783384
# 9             Decision Tree Base        0.994853       0.858718
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 11             Decision Tree GS1        0.880858       0.865696
# 12             Decision Tree GS2        0.880858       0.865696
# 13            Random Forest Base        0.994853       0.895245
# ...

# %% [markdown]
# ### Bernoulli Gridsearch 1

# %%
bernoulli_params = {
    'bernoulli__alpha': [0, 1],
    'bernoulli__force_alpha': [False, True],
    'bernoulli__fit_prior':[True, False],
    'bernoulli__binarize': [None, 0, 1]
}

bernoulli_gs = GridSearchCV(estimator=bernoulli_model, 
                      param_grid=bernoulli_params, 
                      cv=5, 
                      scoring='f1',
                      verbose=1)

bernoulli_gs.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits

# %%
bernoulli_gs.best_params_
# Out:
# {'bernoulli__alpha': 1,
#  'bernoulli__binarize': 0,
#  'bernoulli__fit_prior': False,
#  'bernoulli__force_alpha': False}

# %%
bernoulli_gs.best_score_
# Out:
# 0.6345957082046316

# %% [markdown]
# ### Updating Scorecard

# %%
cv_score_card = cv_score(bernoulli_gs.best_estimator_,
                        'Bernoulli GS1',
                        cv_score_card,
                        X_train,
                        y_train)

# %%
cv_score_card
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression Base        0.798673       0.799492
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 3                       SVC Base        0.675052       0.675052
# 4                        SVM GS1        0.801850       0.801732
# 5                        SVM GS2        0.775327       0.775930
# 6                     NuSVC Base        0.732695       0.734665
# 7                      NuSVC GS1        0.784685       0.783384
# 8                      NuSVC GS2        0.784685       0.783384
# 9             Decision Tree Base        0.994853       0.858718
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 11             Decision Tree GS1        0.880858       0.865696
# 12             Decision Tree GS2        0.880858       0.865696
# 13            Random Forest Base        0.994853       0.895245
# ...

# %% [markdown]
# ## XGBoost

# %%
xgb_model = Pipeline([
    ('ColTrans', ColTrans),
    ('xgb', XGBClassifier(random_state=42))
])

# %%
score_card = score_model(xgb_model, 
                         'XGBoost Base',
                         score_card,
                         X_train,
                         X_test,
                         y_train,
                         y_test)

# %%
score_card
# Out:
#                        Name  Accuracy  Precision    Recall  F1 Score  \
# 0               Dummy Model  0.668332   0.000000  0.000000  0.000000
# 1  Logistic Regression Base  0.797553   0.733209  0.612468  0.667421
# 2                  SVC Base  0.668332   0.000000  0.000000  0.000000
# 3                NuSVC Base  0.753790   0.589855  0.845714  0.694984
# 4        Decision Tree Base  0.865438   0.798851  0.794286  0.796562
# 5        Random Forest Base  0.894728   0.876289  0.794805  0.833560
# 6                  KNN Base  0.836492   0.778539  0.708571  0.741909
# 7            Bernoulli Base  0.746210   0.632474  0.560519  0.594327
# 8              XGBoost Base  0.889731   0.861158  0.795844  0.827214
#
#    ROC/AUC Score
# 0       0.500000
# 1       0.750936
# 2       0.500000
# 3       0.776943
# 4       0.847517
# 5       0.869560
# 6       0.804273
# 7       0.699440
# 8       0.866084

# %%
cv_score_card = cv_score(xgb_model,
                        'XGBoost Base',
                        cv_score_card,
                        X_train,
                        y_train)

# %%
cv_score_card
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression Base        0.798673       0.799492
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 3                       SVC Base        0.675052       0.675052
# 4                        SVM GS1        0.801850       0.801732
# 5                        SVM GS2        0.775327       0.775930
# 6                     NuSVC Base        0.732695       0.734665
# 7                      NuSVC GS1        0.784685       0.783384
# 8                      NuSVC GS2        0.784685       0.783384
# 9             Decision Tree Base        0.994853       0.858718
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 11             Decision Tree GS1        0.880858       0.865696
# 12             Decision Tree GS2        0.880858       0.865696
# 13            Random Forest Base        0.994853       0.895245
# ...

# %% [markdown]
# ### Reducing Overfitting

# %%
XGB_score_card = pd.DataFrame(columns=['Name', 'Train Accuracy', 'Test Accuracy',
                                      'Train Precision', 'Test Precision',
                                      'Train Recall', 'Test Recall',
                                      'Train F1 Score', 'Test F1 Score',
                                      'Train ROC/AUC Score', 'Test ROC/AUC Score'])

# %%
# Base 
XGB_Model_depth = Pipeline([
    ('ColTrans', ColTrans),
    ('xgb', XGBClassifier(random_state=42,
                                 ))
])

XGB_score_card = cv_score(XGB_Model_depth, 
                         'XGBoost Base',
                         XGB_score_card,
                         X_train,
                         y_train)

XGB_score_card
# Out:
#            Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0  XGBoost Base        0.932277       0.889301         0.923181
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.856909      0.863435     0.791621        0.892307        0.82287
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.983358            0.947447     True

# %%
# max Depth = 3
XGB_Model_depth3 = Pipeline([
    ('ColTrans', ColTrans),
    ('xgb', XGBClassifier(random_state=42,
                          max_depth=3
                                 ))
])

XGB_score_card = cv_score(XGB_Model_depth3, 
                         'XGBoost Depth = 3',
                         XGB_score_card,
                         X_train,
                         y_train)

XGB_score_card
# Out:
#                 Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0       XGBoost Base        0.932277       0.889301         0.923181
# 1  XGBoost Depth = 3        0.875291       0.867419         0.845154
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.856909      0.863435     0.791621        0.892307       0.822870
# 1        0.832797      0.754441     0.740852        0.797207       0.784014
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.983358            0.947447     True
# 1             0.940466            0.930013    False

# %%
# max Depth = 4
XGB_Model_depth4 = Pipeline([
    ('ColTrans', ColTrans),
    ('xgb', XGBClassifier(random_state=42,
                          max_depth=4
                                 ))
])

XGB_score_card = cv_score(XGB_Model_depth4, 
                         'XGBoost Depth = 4',
                         XGB_score_card,
                         X_train,
                         y_train)

XGB_score_card
# Out:
#                 Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0       XGBoost Base        0.932277       0.889301         0.923181
# 1  XGBoost Depth = 3        0.875291       0.867419         0.845154
# 2  XGBoost Depth = 4        0.895966       0.881461         0.876906
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.856909      0.863435     0.791621        0.892307       0.822870
# 1        0.832797      0.754441     0.740852        0.797207       0.784014
# 2        0.851077      0.790860     0.770014        0.831660       0.808419
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.983358            0.947447     True
# 1             0.940466            0.930013    False
# 2             0.958332            0.940453    False

# %%
# max Depth = 5 
XGB_Model_depth5 = Pipeline([
    ('ColTrans', ColTrans),
    ('xgb', XGBClassifier(random_state=42,
                          max_depth=5
                                 ))
])

XGB_score_card = cv_score(XGB_Model_depth5, 
                         'XGBoost Depth = 5',
                         XGB_score_card,
                         X_train,
                         y_train)

XGB_score_card
# Out:
#                 Name  Train Accuracy  Test Accuracy  Train Precision  \
# 0       XGBoost Base        0.932277       0.889301         0.923181
# 1  XGBoost Depth = 3        0.875291       0.867419         0.845154
# 2  XGBoost Depth = 4        0.895966       0.881461         0.876906
# 3  XGBoost Depth = 5        0.912528       0.886975         0.896853
#
#    Test Precision  Train Recall  Test Recall  Train F1 Score  Test F1 Score  \
# 0        0.856909      0.863435     0.791621        0.892307       0.822870
# 1        0.832797      0.754441     0.740852        0.797207       0.784014
# 2        0.851077      0.790860     0.770014        0.831660       0.808419
# 3        0.855421      0.825789     0.784860        0.859854       0.818505
#
#    Train ROC/AUC Score  Test ROC/AUC Score Overfit?
# 0             0.983358            0.947447     True
# 1             0.940466            0.930013    False
# 2             0.958332            0.940453    False
# ...

# %% [markdown]
# I will be using max depth of 3. While 4 is still considered 'not overfit'. 3 is less overfit and still has good performance.

# %%
cv_score_card = cv_score(XGB_Model_depth3,
                        'XGBoost Depth = 3',
                        cv_score_card,
                        X_train,
                        y_train)

# %% [markdown]
# ### XGBoost Gridsearch 1

# %% [markdown]
# https://scikit-optimize.github.io/stable/install.html

# %%
xgb_model = Pipeline([
    ('ColTrans', ColTrans),
    ('xgb', XGBClassifier(random_state=42))
])

# %%
xgb_params = {
    'xgb__max_depth': [3],
    'xgb__booster': ['gbtree', 'gblinear', 'dart'],
    'xgb__learning_rate':[.1, .05, .2, .25]
}
xgb_gs = GridSearchCV(estimator=xgb_model, 
                      param_grid=xgb_params, 
                      cv=5, 
                      scoring='f1',
                      verbose=1)

xgb_gs.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [14:01:16] WARNING: D:\bld\xgboost-split_1666900898517\work\src\learner.cc:627:
# Parameters: { "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [14:01:16] WARNING: D:\bld\xgboost-split_1666900898517\work\src\learner.cc:627:
# Parameters: { "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [14:01:16] WARNING: D:\bld\xgboost-split_1666900898517\work\src\learner.cc:627:
# ...

# %%
xgb_gs.best_params_
# Out:
# {'xgb__booster': 'gbtree', 'xgb__learning_rate': 0.25, 'xgb__max_depth': 3}

# %%
xgb_gs.best_score_
# Out:
# 0.7815675923875555

# %% [markdown]
# ### XGBoost Gridsearch 2

# %%
xgb_params2 = {
    'xgb__max_depth': [3],
    'xgb__booster': ['gbtree', ],
    'xgb__learning_rate':[.25],
    'xgb__n_estimators':[100, 200, 300]
}
xgb_gs2 = GridSearchCV(estimator=xgb_model, 
                      param_grid=xgb_params2, 
                      cv=5, 
                      scoring='f1',
                      verbose=1)

xgb_gs2.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits

# %%
xgb_gs2.best_params_
# Out:
# {'xgb__booster': 'gbtree',
#  'xgb__learning_rate': 0.25,
#  'xgb__max_depth': 3,
#  'xgb__n_estimators': 300}

# %%
xgb_gs2.best_score_
# Out:
# 0.806065000304503

# %% [markdown]
# ### Updating Scorecard

# %%
# updating GS 1
cv_score_card = cv_score(xgb_gs.best_estimator_, 
                         'XGB GS1',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
# updating GS 2
cv_score_card = cv_score(xgb_gs2.best_estimator_, 
                         'XGB GS2',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
cv_score_card
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression Base        0.798673       0.799492
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 3                       SVC Base        0.675052       0.675052
# 4                        SVM GS1        0.801850       0.801732
# 5                        SVM GS2        0.775327       0.775930
# 6                     NuSVC Base        0.732695       0.734665
# 7                      NuSVC GS1        0.784685       0.783384
# 8                      NuSVC GS2        0.784685       0.783384
# 9             Decision Tree Base        0.994853       0.858718
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 11             Decision Tree GS1        0.880858       0.865696
# 12             Decision Tree GS2        0.880858       0.865696
# 13            Random Forest Base        0.994853       0.895245
# ...

# %% [markdown]
# ## XGB Random Forest

# %%
xgbrf_model = Pipeline([
    ('ColTrans', ColTrans),
    ('xgbrf', XGBRFClassifier(random_state=42))
])

# %%
score_card = score_model(xgbrf_model, 
                         'XGB Random Forest',
                         score_card,
                         X_train,
                         X_test,
                         y_train,
                         y_test)

# %%
score_card
# Out:
#                        Name  Accuracy  Precision    Recall  F1 Score  \
# 0               Dummy Model  0.668332   0.000000  0.000000  0.000000
# 1  Logistic Regression Base  0.797553   0.733209  0.612468  0.667421
# 2                  SVC Base  0.668332   0.000000  0.000000  0.000000
# 3                NuSVC Base  0.753790   0.589855  0.845714  0.694984
# 4        Decision Tree Base  0.865438   0.798851  0.794286  0.796562
# 5        Random Forest Base  0.894728   0.876289  0.794805  0.833560
# 6                  KNN Base  0.836492   0.778539  0.708571  0.741909
# 7            Bernoulli Base  0.746210   0.632474  0.560519  0.594327
# 8              XGBoost Base  0.889731   0.861158  0.795844  0.827214
# 9         XGB Random Forest  0.861130   0.828924  0.732468  0.777716
#
#    ROC/AUC Score
# 0       0.500000
# 1       0.750936
# 2       0.500000
# 3       0.776943
# 4       0.847517
# 5       0.869560
# 6       0.804273
# 7       0.699440
# 8       0.866084
# 9       0.828724

# %%
cv_score_card = cv_score(xgbrf_model,
                         'XGB Random Forest Base',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
cv_score_card
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression Base        0.798673       0.799492
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 3                       SVC Base        0.675052       0.675052
# 4                        SVM GS1        0.801850       0.801732
# 5                        SVM GS2        0.775327       0.775930
# 6                     NuSVC Base        0.732695       0.734665
# 7                      NuSVC GS1        0.784685       0.783384
# 8                      NuSVC GS2        0.784685       0.783384
# 9             Decision Tree Base        0.994853       0.858718
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 11             Decision Tree GS1        0.880858       0.865696
# 12             Decision Tree GS2        0.880858       0.865696
# 13            Random Forest Base        0.994853       0.895245
# ...

# %% [markdown]
# ### XGB Random Forest Gridsearch 1

# %%
xgbrf_params = {
    'xgbrf__max_depth': [5, 6, 7],
    'xgbrf__n_estimators':[100, 200, 300, 400]
}
xgbrf_gs = GridSearchCV(estimator=xgbrf_model, 
                      param_grid=xgbrf_params, 
                      cv=5, 
                      scoring='f1',
                      verbose=1)

xgbrf_gs.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
xgbrf_gs.best_params_
# Out:
# {'xgbrf__max_depth': 7, 'xgbrf__n_estimators': 100}

# %%
xgbrf_gs.best_score_
# Out:
# 0.7809986544356565

# %% [markdown]
# ### XGB Random Forest Gridsearch 2

# %%
xgbrf_params2 = {
    'xgbrf__max_depth': [6, 7],
    'xgbrf__learning_rate':[.05, .1, .25],
    'xgbrf__n_estimators':[50, 100, 200]
}
xgbrf_gs2 = GridSearchCV(estimator=xgbrf_model, 
                      param_grid=xgbrf_params2, 
                      cv=5, 
                      scoring='f1',
                      verbose=1)

xgbrf_gs2.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits

# %%
xgbrf_gs2.best_params_
# Out:
# {'xgbrf__learning_rate': 0.05,
#  'xgbrf__max_depth': 7,
#  'xgbrf__n_estimators': 100}

# %%
xgbrf_gs2.best_score_
# Out:
# 0.7809986544356565

# %% [markdown]
# ### Updating Scorecard

# %%
# updating GS 1
cv_score_card = cv_score(xgbrf_gs.best_estimator_, 
                         'XGB RF GS1',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
# updating GS 1
cv_score_card = cv_score(xgbrf_gs2.best_estimator_, 
                         'XGB RF GS2',
                         cv_score_card,
                         X_train,
                         y_train)

# %%
cv_score_card
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression Base        0.798673       0.799492
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 3                       SVC Base        0.675052       0.675052
# 4                        SVM GS1        0.801850       0.801732
# 5                        SVM GS2        0.775327       0.775930
# 6                     NuSVC Base        0.732695       0.734665
# 7                      NuSVC GS1        0.784685       0.783384
# 8                      NuSVC GS2        0.784685       0.783384
# 9             Decision Tree Base        0.994853       0.858718
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 11             Decision Tree GS1        0.880858       0.865696
# 12             Decision Tree GS2        0.880858       0.865696
# 13            Random Forest Base        0.994853       0.895245
# ...

# %% [markdown]
# ## Stacking Classifier

# %% [markdown]
# Deciding which models to use:

# %%
potential_df = cv_score_card[(cv_score_card['Overfit?'] == 'False') &
                             (cv_score_card['Test Accuracy'] >.8)]

# %%
potential_df
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 4                        SVM GS1        0.801850       0.801732
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 11             Decision Tree GS1        0.880858       0.865696
# 12             Decision Tree GS2        0.880858       0.865696
# 14  Random Forest Max Depth = 10        0.888837       0.874009
# 15             Random Forest GS1        0.882915       0.868970
# 16             Random Forest GS2        0.883184       0.869616
# 18            KNN Neighbors = 29        0.826251       0.811509
# 24             XGBoost Depth = 3        0.875291       0.867419
# 25                       XGB GS1        0.872006       0.866385
# 27        XGB Random Forest Base        0.862961       0.857469
# 28                    XGB RF GS1        0.871156       0.865524
# ...

# %% [markdown]
# Duplicates include:
#
#     - All Decision Trees
#     - XGBRF GS1 & GS2
#
# Below I will clean the DF to remove duplicates:

# %%
potential_df = potential_df.drop_duplicates(subset=['Train Accuracy', 'Test Accuracy'])

# %%
potential_df
# Out:
#                             Name  Train Accuracy  Test Accuracy  \
# 1        Logistic Regression GS1        0.804424       0.803670
# 2        Logistic Regression GS2        0.804198       0.804187
# 4                        SVM GS1        0.801850       0.801732
# 10   Decision Tree Max Depth = 9        0.880858       0.865696
# 14  Random Forest Max Depth = 10        0.888837       0.874009
# 15             Random Forest GS1        0.882915       0.868970
# 16             Random Forest GS2        0.883184       0.869616
# 18            KNN Neighbors = 29        0.826251       0.811509
# 24             XGBoost Depth = 3        0.875291       0.867419
# 25                       XGB GS1        0.872006       0.866385
# 27        XGB Random Forest Base        0.862961       0.857469
# 28                    XGB RF GS1        0.871156       0.865524
#
#     Train Precision  Test Precision  Train Recall  Test Recall  \
# 1          0.734888        0.734054      0.622813     0.620758
# ...

# %% [markdown]
# Picking the best performers from what's remaining:
#
# - LR GS2
# - SVM GS1
# - Decision Tree Max Depth = 10
# - Random Forest GS2
# - KNN Neighbors = 29
# - XGB Depth = 3
# - XGB RF GS1

# %%
ensemble_df = potential_df.loc[[2, 4, 10, 16, 18, 24, 28]]

# %%
ensemble_df
# Out:
#                            Name  Train Accuracy  Test Accuracy  \
# 2       Logistic Regression GS2        0.804198       0.804187
# 4                       SVM GS1        0.801850       0.801732
# 10  Decision Tree Max Depth = 9        0.880858       0.865696
# 16            Random Forest GS2        0.883184       0.869616
# 18           KNN Neighbors = 29        0.826251       0.811509
# 24            XGBoost Depth = 3        0.875291       0.867419
# 28                   XGB RF GS1        0.871156       0.865524
#
#     Train Precision  Test Precision  Train Recall  Test Recall  \
# 2          0.734889        0.735074      0.621719     0.621421
# 4          0.723538        0.724072      0.631561     0.630037
# 10         0.847998        0.820975      0.772733     0.751458
# 16         0.816703        0.795668      0.825954     0.805936
# 18         0.802706        0.775513      0.616980     0.591064
# 24         0.845154        0.832797      0.754441     0.740852
# ...

# %% [markdown]
# ### Stacking 1

# %%
estimators = [
    ('xgbrf', xgbrf_gs.best_estimator_[1])
]

# %%
stack_model = Pipeline([
    ('ColTrans', ColTrans),
    ('stack', StackingClassifier(estimators))
])

# %%
ensemble_df = cv_score(stack_model,
                        'Stacking 1',
                        ensemble_df,
                        X_train,
                        y_train)

# %%
ensemble_df
# Out:
#                           Name  Train Accuracy  Test Accuracy  \
# 0      Logistic Regression GS2        0.804198       0.804187
# 1                      SVM GS1        0.801850       0.801732
# 2  Decision Tree Max Depth = 9        0.880858       0.865696
# 3            Random Forest GS2        0.883184       0.869616
# 4           KNN Neighbors = 29        0.826251       0.811509
# 5            XGBoost Depth = 3        0.875291       0.867419
# 6                   XGB RF GS1        0.871156       0.865524
# 7                   Stacking 1        0.871576       0.865912
#
#    Train Precision  Test Precision  Train Recall  Test Recall  Train F1 Score  \
# 0         0.734889        0.735074      0.621719     0.621421        0.673581
# 1         0.723538        0.724072      0.631561     0.630037        0.674347
# 2         0.847998        0.820975      0.772733     0.751458        0.808206
# 3         0.816703        0.795668      0.825954     0.805936        0.821277
# ...

# %% [markdown]
# ###  Stacking 2

# %%
estimators = [
    ('xgb', XGB_Model_depth3[1]),
    ('xgbrf', xgbrf_gs.best_estimator_[1])
]

# %%
stack_model = Pipeline([
    ('ColTrans', ColTrans),
    ('stack', StackingClassifier(estimators))
])

# %%
ensemble_df = cv_score(stack_model,
                        'Stacking 2',
                        ensemble_df,
                        X_train,
                        y_train)

# %%
ensemble_df
# Out:
#                           Name  Train Accuracy  Test Accuracy  \
# 0      Logistic Regression GS2        0.804198       0.804187
# 1                      SVM GS1        0.801850       0.801732
# 2  Decision Tree Max Depth = 9        0.880858       0.865696
# 3            Random Forest GS2        0.883184       0.869616
# 4           KNN Neighbors = 29        0.826251       0.811509
# 5            XGBoost Depth = 3        0.875291       0.867419
# 6                   XGB RF GS1        0.871156       0.865524
# 7                   Stacking 1        0.871576       0.865912
# 8                   Stacking 2        0.877983       0.870779
#
#    Train Precision  Test Precision  Train Recall  Test Recall  Train F1 Score  \
# 0         0.734889        0.735074      0.621719     0.621421        0.673581
# 1         0.723538        0.724072      0.631561     0.630037        0.674347
# 2         0.847998        0.820975      0.772733     0.751458        0.808206
# ...

# %% [markdown]
# ### Stacking 3

# %%
estimators = [
    ('knn', KNN_Model_neighbors29[1]),
    ('xgb', XGB_Model_depth3[1]),
    ('xgbrf', xgbrf_gs.best_estimator_[1])
]

# %%
stack_model = Pipeline([
    ('ColTrans', ColTrans),
    ('stack', StackingClassifier(estimators))
])

# %%
ensemble_df = cv_score(stack_model,
                        'Stacking 3',
                        ensemble_df,
                        X_train,
                        y_train)

# %%
ensemble_df
# Out:
#                           Name  Train Accuracy  Test Accuracy  \
# 0      Logistic Regression GS2        0.804198       0.804187
# 1                      SVM GS1        0.801850       0.801732
# 2  Decision Tree Max Depth = 9        0.880858       0.865696
# 3            Random Forest GS2        0.883184       0.869616
# 4           KNN Neighbors = 29        0.826251       0.811509
# 5            XGBoost Depth = 3        0.875291       0.867419
# 6                   XGB RF GS1        0.871156       0.865524
# 7                   Stacking 1        0.871576       0.865912
# 8                   Stacking 2        0.877983       0.870779
# 9                   Stacking 3        0.880696       0.873406
#
#    Train Precision  Test Precision  Train Recall  Test Recall  Train F1 Score  \
# 0         0.734889        0.735074      0.621719     0.621421        0.673581
# 1         0.723538        0.724072      0.631561     0.630037        0.674347
# ...

# %% [markdown]
# ### Stacking 4

# %%
estimators = [
    ('RF', rf_gs2.best_estimator_[1]),
    ('knn', KNN_Model_neighbors29[1]),
    ('xgb', XGB_Model_depth3[1]),
    ('xgbrf', xgbrf_gs.best_estimator_[1])
]

# %%
stack_model = Pipeline([
    ('ColTrans', ColTrans),
    ('stack', StackingClassifier(estimators))
])

# %%
ensemble_df = cv_score(stack_model,
                        'Stacking 4',
                        ensemble_df,
                        X_train,
                        y_train)

# %%
ensemble_df
# Out:
#                            Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression GS2        0.804198       0.804187
# 1                       SVM GS1        0.801850       0.801732
# 2   Decision Tree Max Depth = 9        0.880858       0.865696
# 3             Random Forest GS2        0.883184       0.869616
# 4            KNN Neighbors = 29        0.826251       0.811509
# 5             XGBoost Depth = 3        0.875291       0.867419
# 6                    XGB RF GS1        0.871156       0.865524
# 7                    Stacking 1        0.871576       0.865912
# 8                    Stacking 2        0.877983       0.870779
# 9                    Stacking 3        0.880696       0.873406
# 10                   Stacking 4        0.885198       0.875948
#
#     Train Precision  Test Precision  Train Recall  Test Recall  \
# 0          0.734889        0.735074      0.621719     0.621421
# 1          0.723538        0.724072      0.631561     0.630037
# ...

# %% [markdown]
# ### Stacking 5

# %%
estimators = [
    ('DT', DT_model_depth9[1]),
    ('RF', rf_gs2.best_estimator_[1]),
    ('knn', KNN_Model_neighbors29[1]),
    ('xgb', XGB_Model_depth3[1]),
    ('xgbrf', xgbrf_gs.best_estimator_[1])
]

# %%
stack_model = Pipeline([
    ('ColTrans', ColTrans),
    ('stack', StackingClassifier(estimators))
])

# %%
ensemble_df = cv_score(stack_model,
                        'Stacking 5',
                        ensemble_df,
                        X_train,
                        y_train)

# %%
ensemble_df
# Out:
#                            Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression GS2        0.804198       0.804187
# 1                       SVM GS1        0.801850       0.801732
# 2   Decision Tree Max Depth = 9        0.880858       0.865696
# 3             Random Forest GS2        0.883184       0.869616
# 4            KNN Neighbors = 29        0.826251       0.811509
# 5             XGBoost Depth = 3        0.875291       0.867419
# 6                    XGB RF GS1        0.871156       0.865524
# 7                    Stacking 1        0.871576       0.865912
# 8                    Stacking 2        0.877983       0.870779
# 9                    Stacking 3        0.880696       0.873406
# 10                   Stacking 4        0.885198       0.875948
# 11                   Stacking 5        0.889397       0.877111
#
#     Train Precision  Test Precision  Train Recall  Test Recall  \
# 0          0.734889        0.735074      0.621719     0.621421
# ...

# %% [markdown]
# ### Stacking 6

# %%
estimators = [
    ('SVC', svc_gs1.best_estimator_[1]),
    ('DT', DT_model_depth9[1]),
    ('RF', rf_gs2.best_estimator_[1]),
    ('knn', KNN_Model_neighbors29[1]),
    ('xgb', XGB_Model_depth3[1]),
    ('xgbrf', xgbrf_gs.best_estimator_[1])
]

# %%
stack_model = Pipeline([
    ('ColTrans', ColTrans),
    ('stack', StackingClassifier(estimators))
])

# %%
ensemble_df = cv_score(stack_model,
                        'Stacking 6',
                        ensemble_df,
                        X_train,
                        y_train)

# %%
ensemble_df
# Out:
#                            Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression GS2        0.804198       0.804187
# 1                       SVM GS1        0.801850       0.801732
# 2   Decision Tree Max Depth = 9        0.880858       0.865696
# 3             Random Forest GS2        0.883184       0.869616
# 4            KNN Neighbors = 29        0.826251       0.811509
# 5             XGBoost Depth = 3        0.875291       0.867419
# 6                    XGB RF GS1        0.871156       0.865524
# 7                    Stacking 1        0.871576       0.865912
# 8                    Stacking 2        0.877983       0.870779
# 9                    Stacking 3        0.880696       0.873406
# 10                   Stacking 4        0.885198       0.875948
# 11                   Stacking 5        0.889397       0.877111
# 12                   Stacking 6        0.891013       0.878145
#
#     Train Precision  Test Precision  Train Recall  Test Recall  \
# ...

# %% [markdown]
# ### Stacking Final

# %%
estimators = [
    ('logreg', lr_gs2.best_estimator_[1]),
    ('SVC', svc_gs1.best_estimator_[1]),
    ('DT', DT_model_depth9[1]),
    ('RF', rf_gs2.best_estimator_[1]),
    ('knn', KNN_Model_neighbors29[1]),
    ('xgb', XGB_Model_depth3[1]),
    ('xgbrf', xgbrf_gs.best_estimator_[1])
]

# %%
stack_model = Pipeline([
    ('ColTrans', ColTrans),
    ('stack', StackingClassifier(estimators))
])

# %%
ensemble_df = cv_score(stack_model,
                        'Stacking ALL',
                        ensemble_df,
                        X_train,
                        y_train)

# %%
ensemble_df
# Out:
#                            Name  Train Accuracy  Test Accuracy  \
# 0       Logistic Regression GS2        0.804198       0.804187
# 1                       SVM GS1        0.801850       0.801732
# 2   Decision Tree Max Depth = 9        0.880858       0.865696
# 3             Random Forest GS2        0.883184       0.869616
# 4            KNN Neighbors = 29        0.826251       0.811509
# 5             XGBoost Depth = 3        0.875291       0.867419
# 6                    XGB RF GS1        0.871156       0.865524
# 7                    Stacking 1        0.871576       0.865912
# 8                    Stacking 2        0.877983       0.870779
# 9                    Stacking 3        0.880696       0.873406
# 10                   Stacking 4        0.885198       0.875948
# 11                   Stacking 5        0.889397       0.877111
# 12                   Stacking 6        0.891013       0.878145
# 13                 Stacking ALL        0.890560       0.878231
#
# ...

# %% [markdown]
# ## Checking Against Validation Data

# %% [markdown]
# First checking train vs test data.

# %%
final_score = pd.DataFrame(columns=['Name', 'Accuracy', 'Precision', 'Recall', 
                                    'F1 Score', 'ROC/AUC Score'])

# %%
final_score = score_model(stack_model,
                          'Test Data',
                          final_score,
                          X_train=X_train,
                          X_test=X_test,
                          y_train=y_train,
                          y_test=y_test)

# %%
final_score = score_model(stack_model,
                          'Validation Data',
                          final_score,
                          X_train=X_total,
                          X_test=X_val,
                          y_train=y_total,
                          y_test=y_val)

# %%
final_score
# Out:
#               Name  Accuracy  Precision   Recall  F1 Score  ROC/AUC Score
# 0        Test Data  0.880083   0.839315  0.78961  0.813704       0.857296
# 1  Validation Data  0.879531   0.843277  0.78394  0.812527       0.855599

# %% [markdown]
# ## Results

# %% [markdown]
# The final stacking classifier performs well on both the test data and the set aside validation data. The model is able to predict whether a guest will cancel their stay with an 88% accuracy rate and with a precision of 84%.
#
# Being able to predict whether a guest is likely to cancel would be a huge benefit to the hotel. Having an idea of potential cancellations would allow management to better plan for staffing, food budgets, and other commodities that depend on guest levels.

# %% [markdown]
# ![hotel_closing](./Images/closing_image.jpg)

# %% [markdown]
# # Conclusion and Recommendations

# %% [markdown]
# ## Recap of Initial Results

# %% [markdown]
# This [initial data discovery phase](./Hotel_Cancellation_Introduction.ipynb) shows five focus areas to increase revenue and decrease cancellations.
#
# **1) Number of Adults:**
# Single adults and groups of 4 have the lowest cancellation rates while 2 or 3 adults per room have the highest amount of cancellations. Groups of 4 adults only cancel their reservation at a rate of about 19% while rooms with no adults or 2-3 adults all cancel more than 30% of the time.
#
# Additionally, when looking at the average price of a room by the number of adults staying, we can see that the price of the room increases as the number of adults increases. The average price of a room for only one adult is about \\$95 while the average price of a room for four adults is about $200.
#
# In order to reduce the likelihood of cancellation while simultaneously increasing revenue, it is suggested to promote bookings for groups of four adults.

# %% [markdown]
# **2) Total Length of Stay:** There is a sharp jump in cancellation rates based on total stay after about 11 total nights booked. This makes sense when we think of a booking encompassing an initial Friday night stay and then checking out the Sunday of the following weekend. There's about a 37% cancellation rate for bookings with stays 11 days or less, while stays over 11 days have a cancellation rate of about 81%.
#
# When we look at the total length of a stay in relation to price, we see a similar trend when compared to cancellation rates. The average price per room is pretty consistent despite the length of the stay until the number of nights booked is longer than about 2 weeks. After the two week mark, we start to see some increased volatility in price. The average daily room price for stays less than 2 weeks is $105 while the average daily price for stays longer than 2 weeks is only about \\$90.
#
# In order to reduce the likelihood of cancellation while simultaneously increasing revenue, it is suggested to promote bookings for stays less than 11-14 days.

# %% [markdown]
# **3) Parking Requirements:** With only two options on this binary feature, we can clearly see that guests who require a parking space have a cancellation rate of only about 10% while guests who do not require a parking space cancel about 1/3rd of the time.
#
# When we look at parking requirements in relation to price, we can see that guests who require parking have an average room price of \\$119 when compared to guests who do not require parking at an average price of \\$105. This makes sense as guests are likely to pay a premium if they have a car and need a place to stay.
#
# In order to reduce the likelihood of cancellation while simultaneously increasing revenue, it is suggested to promote bookings for guests who require parking by either targeting guests who are traveling on a road trip or renting a car in a city that they've flown to.

# %% [markdown]
# **4) Special Requests:** When we look at the number of special requests that guests make in relation to cancellation rates, we can see a clear trend where the more requests made reduces the likelihood of cancellation. About 43% of guests without a special request end up canceling their reservation while only 24% of guests with one request and 15% of guests with 2 requests cancel their reservations. Guests with 3 or more special requests have a zero percent cancellation rate.
#
# When we look at the number of special requests in relation to pricing, we can see another clear trend where guests who make more requests pay more for their room. Guests with no special requests pay an average rate of \\$100 per night while guests who make one or more request pay an average price of \\$119 per night.
#
# In order to reduce the likelihood of cancellation while simultaneously increasing revenue, it is suggested to promote bookings for guests who make special requests.

# %% [markdown]
# **5) Booking Lead Time Prior to Stay:** When looking at how far out guests are booking their hotel stays, we can see a clear jump in cancellation rate when guests book more the 150 days out. The average cancellation rate for guests who book within 150 days of their stay is only 29% while guests who book more than 150 days in advance cancel at an average rate of 70%.
#
# When looking at the booking lead time in relation to price, we see a similar trend when compared to cancellation rates. The average price per room for stays booked within 200 days of a stay is about \\$105 per night. Stays booked more than 200 days in advance have an average nightly price of about \\$96.
#
# In order to reduce the likelihood of cancellation while simultaneously increasing revenue, it is suggested to promote bookings for stays less than 150-200 days out.

# %% [markdown]
# ## Modeling Results

# %% [markdown]
# The modeling agrees with the initial data analysis. Feature importance taken from the Random Forest model lists the 5 most important features as:
#
# - `lead_time`
# - `no_of_special_requests`
# - `avg_price_per_room`
# - `total_stay_price`
# - `arrival_month`
#
# It is the recommendation of this analysis that prioritizing booking lead time to a window less than 150-200 days out, and offering guests the opportunity to customize their stay with special requests will lead to higher revenues and less cancellations.
